# %%
# Import required libraries and dependencies
import pandas as pd
import hvplot.pandas
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
# Load the data into a Pandas DataFrame
df_market_data = pd.read_csv(
    "Resources/crypto_market_data.csv",
    index_col="coin_id")

# Display sample data
df_market_data.head(10)
# Out:
#                  price_change_percentage_24h  price_change_percentage_7d  \
# coin_id
# bitcoin                              1.08388                     7.60278
# ethereum                             0.22392                    10.38134
# tether                              -0.21173                     0.04935
# ripple                              -0.37819                    -0.60926
# bitcoin-cash                         2.90585                    17.09717
# binancecoin                          2.10423                    12.85511
# chainlink                           -0.23935                    20.69459
# cardano                              0.00322                    13.99302
# litecoin                            -0.06341                     6.60221
# bitcoin-cash-sv                      0.92530                     3.29641
#
#                  price_change_percentage_14d  price_change_percentage_30d  \
# coin_id
# ...

# %%
# Generate summary statistics
df_market_data.describe()
# Out:
#        price_change_percentage_24h  price_change_percentage_7d  \
# count                    41.000000                   41.000000
# mean                     -0.269686                    4.497147
# std                       2.694793                    6.375218
# min                     -13.527860                   -6.094560
# 25%                      -0.608970                    0.047260
# 50%                      -0.063410                    3.296410
# 75%                       0.612090                    7.602780
# max                       4.840330                   20.694590
#
#        price_change_percentage_14d  price_change_percentage_30d  \
# count                    41.000000                    41.000000
# mean                      0.185787                     1.545693
# std                       8.376939                    26.344218
# min                     -18.158900                   -34.705480
# 25%                      -5.026620                   -10.438470
# ...

# %%
# Plot your data to see what's in your DataFrame
df_market_data.hvplot.line(
    width=800,
    height=400,
    rot=90
)
# Get a list of all column names
column_names = df_market_data.columns.tolist()

# Print the list of column names
print(column_names)
# Out:
# ['price_change_percentage_24h', 'price_change_percentage_7d', 'price_change_percentage_14d', 'price_change_percentage_30d', 'price_change_percentage_60d', 'price_change_percentage_200d', 'price_change_percentage_1y']

# %% [markdown]
# ---

# %% [markdown]
# ### Prepare the Data

# %%
# Use the `StandardScaler()` module from scikit-learn to normalize the data from the CSV file
features = df_market_data[['price_change_percentage_24h', 'price_change_percentage_7d', 'price_change_percentage_14d', 'price_change_percentage_30d', 'price_change_percentage_60d', 'price_change_percentage_200d', 'price_change_percentage_1y']]
scaler = StandardScaler()
normalized_features = scaler.fit_transform(features)

# %%
# Create a DataFrame with the scaled data
normalized_df = pd.DataFrame(normalized_features, columns=features.columns)
# Copy the crypto names from the original data
normalized_df['coin_id'] = df_market_data.index
# Set the coinid column as index
normalized_df.set_index('coin_id', inplace=True)

# Display sample data
normalized_df.head()
# Out:
#               price_change_percentage_24h  price_change_percentage_7d  \
# coin_id
# bitcoin                          0.508529                    0.493193
# ethereum                         0.185446                    0.934445
# tether                           0.021774                   -0.706337
# ripple                          -0.040764                   -0.810928
# bitcoin-cash                     1.193036                    2.000959
#
#               price_change_percentage_14d  price_change_percentage_30d  \
# coin_id
# bitcoin                          0.772200                     0.235460
# ethereum                         0.558692                    -0.054341
# tether                          -0.021680                    -0.061030
# ripple                           0.249458                    -0.050388
# bitcoin-cash                     1.760610                     0.545842
#
#               price_change_percentage_60d  price_change_percentage_200d  \
# coin_id
# ...

# %% [markdown]
# ---

# %% [markdown]
# ### Find the Best Value for k Using the Original Data.

# %%
# Create a list with the number of k-values from 1 to 11
k_values = list(range(1, 12))

# %%
# Create an empty list to store the inertia values
inertia_values = []

# Create a for loop to compute the inertia with each possible value of k
# Inside the loop:
# 1. Create a KMeans model using the loop counter for the n_clusters
# 2. Fit the model to the data using `normalized_df`
# 3. Append the model.inertia_ to the inertia list
for k in k_values:
    kmeans = KMeans(n_clusters=k)
    kmeans.fit(normalized_df)
    inertia_values.append(kmeans.inertia_)
print(inertia_values)
# Out:
# C:\Users\GamingPC\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\GamingPC\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\GamingPC\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ...

# %%
# Create a dictionary with the data to plot the Elbow curve
elbow_data = {'K': list(range(1, 12)),
              'Inertia': inertia_values}

# Create a DataFrame with the data to plot the Elbow curve
elbow_df = pd.DataFrame(elbow_data)
print(elbow_df)
# Out:
#      K     Inertia
# 0    1  287.000000
# 1    2  198.571818
# 2    3  123.190482
# 3    4   79.022435
# 4    5   65.605778
# 5    6   53.057788
# 6    7   43.914690
# 7    8   36.851477
# 8    9   32.621433
# 9   10   28.866775
# 10  11   24.771468

# %%
# Plot a line chart with all the inertia values computed with 
# the different values of k to visually identify the optimal value for k.
line_plot1 = elbow_df.hvplot.line(
    x='K',
    y='Inertia',
    xlabel='Number of Clusters (K)',
    ylabel='Inertia',
    title='Elbow Curve'
)
line_plot1
# Out:
# :Curve   [K]   (Inertia)

# %% [markdown]
# #### Answer the following question:
#
# **Question:** What is the best value for `k`?
#
# **Answer:** 4

# %% [markdown]
# ---

# %% [markdown]
# ### Cluster Cryptocurrencies with K-means Using the Original Data

# %%
# Initialise the K-Means model using the best value for k
kmeans = KMeans(n_clusters=4)

# %%
# Fit the K-Means model using the scaled data
kmeans.fit(normalized_df)
# Out:
# C:\Users\GamingPC\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\GamingPC\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# KMeans(n_clusters=4)

# %%
# Predict the clusters to group the cryptocurrencies using the scaled data
cluster_centers = kmeans.cluster_centers_

# Print the resulting array of cluster values.
labels = kmeans.labels_

# %%
# Create a copy of the DataFrame
normalized_df_copy = normalized_df.copy()

# Display the copied DataFrame
print("Copied DataFrame:")
print(normalized_df_copy)
# Out:
# Copied DataFrame:
#                       price_change_percentage_24h  price_change_percentage_7d  \
# coin_id
# bitcoin                                  0.508529                    0.493193
# ethereum                                 0.185446                    0.934445
# tether                                   0.021774                   -0.706337
# ripple                                  -0.040764                   -0.810928
# bitcoin-cash                             1.193036                    2.000959
# binancecoin                              0.891871                    1.327295
# chainlink                                0.011397                    2.572251
# cardano                                  0.102530                    1.508001
# litecoin                                 0.077497                    0.334297
# bitcoin-cash-sv                          0.448952                   -0.190684
# crypto-com-chain                         0.331280                   -1.614844
# ...

# %%
# Add a new column to the DataFrame with the predicted clusters
normalized_df_copy['Cluster'] = labels


# Display sample data
print("DataFrame with Predicted Clusters:")
print(normalized_df_copy.head())
# Out:
# DataFrame with Predicted Clusters:
#               price_change_percentage_24h  price_change_percentage_7d  \
# coin_id
# bitcoin                          0.508529                    0.493193
# ethereum                         0.185446                    0.934445
# tether                           0.021774                   -0.706337
# ripple                          -0.040764                   -0.810928
# bitcoin-cash                     1.193036                    2.000959
#
#               price_change_percentage_14d  price_change_percentage_30d  \
# coin_id
# bitcoin                          0.772200                     0.235460
# ethereum                         0.558692                    -0.054341
# tether                          -0.021680                    -0.061030
# ripple                           0.249458                    -0.050388
# bitcoin-cash                     1.760610                     0.545842
#
# ...

# %%
# Create a scatter plot using hvPlot by setting 
# `x="price_change_percentage_24h"` and `y="price_change_percentage_7d"`. 
# Colour the graph points with the labels found using K-Means and 
# add the crypto name in the `hover_cols` parameter to identify 
# the cryptocurrency represented by each data point.

scatter_plot = normalized_df_copy.hvplot.scatter(
    x="price_change_percentage_24h",
    y="price_change_percentage_7d",
    by='Cluster',
    hover_cols=["coin_id"],
    legend='bottom_right',
    title="Crypto Scatter Plot"
)

# Show the plot
scatter_plot
# Out:
# :NdOverlay   [Cluster]
#    :Scatter   [price_change_percentage_24h]   (price_change_percentage_7d,coin_id)

# %% [markdown]
# ---

# %% [markdown]
# ### Optimise Clusters with Principal Component Analysis.

# %%
# Create a PCA model instance and set `n_components=3`.
pca_model = PCA(n_components=3)

# %%
# Use the PCA model with `fit_transform` to reduce to 
# three principal components.
pca_components = pca_model.fit_transform(normalized_df_copy)
pca_df = pd.DataFrame(pca_components, columns=['PC1', 'PC2', 'PC3'])
# View the first five rows of the DataFrame. 
print(pca_df)
# Out:
#          PC1       PC2       PC3
# 0  -0.989271  0.715160  0.493822
# 1  -0.801150  0.386863  1.010012
# 2  -0.257238 -0.294368 -0.715437
# 3  -0.289312 -0.354596 -0.561213
# 4  -1.849888  1.754733  1.711689
# 5  -1.052689  1.268868  0.805956
# 6  -0.914743  0.474010  2.839876
# 7  -0.787229  0.684855  1.517126
# 8  -0.951595  0.308202  0.646095
# 9  -0.575981 -0.401578 -0.341627
# 10  0.230345 -1.428433 -1.421837
# 11 -0.259287 -0.303008 -0.736719
# 12 -0.435761 -0.653589 -0.620830
# 13 -0.893580  2.893367  1.457651
# 14 -0.269429 -0.217198 -0.105335
# 15 -0.910694 -0.616663  1.150621
# 16  0.472679 -1.241448 -1.034723
# 17 -0.217389 -0.845364 -0.128295
# 18 -0.760252  0.673455  1.755050
# 19 -0.336218 -0.290311 -0.741309
# 20 -0.007123 -1.068834 -0.740826
# 21 -0.987861  0.699065  0.472583
# 22 -0.103437 -0.784605 -1.102742
# 23 -0.240332 -0.326532 -0.428615
# 24  0.575512  0.665781 -1.125627
# 25 -0.276506 -0.282223 -0.724053
# 26 -0.536650 -0.702452  0.087661
# ...

# %%
# Retrieve the explained variance to determine how much information 
# can be attributed to each principal component.
explained_variance = pca_model.explained_variance_
print("Explained Variance for Each Principal Component:")
for i, variance in enumerate(explained_variance):
    print(f"PC{i+1}: {variance:.3f}")
total_explained_variance = sum(explained_variance)

# Display the total explainable variance
print("Total Explained Variance:", total_explained_variance)
# Out:
# Explained Variance for Each Principal Component:
# PC1: 2.885
# PC2: 2.508
# PC3: 1.335
# Total Explained Variance: 6.727567572359515

# %% [markdown]
# #### Answer the following question:
#
# **Question:** What is the total explained variance of the three principal components?
#
# **Answer:** 7.175195939807998

# %%
# Create a new DataFrame with the PCA data.
pca_data = pca_df.copy()
# Copy the crypto names from the original data
pca_data.index = normalized_df_copy.index

# Display sample data
print("DataFrame with PCA Data:")
print(pca_data.head())
# Out:
# DataFrame with PCA Data:
#                    PC1       PC2       PC3
# coin_id
# bitcoin      -0.989271  0.715160  0.493822
# ethereum     -0.801150  0.386863  1.010012
# tether       -0.257238 -0.294368 -0.715437
# ripple       -0.289312 -0.354596 -0.561213
# bitcoin-cash -1.849888  1.754733  1.711689

# %% [markdown]
# ---

# %% [markdown]
# ### Find the Best Value for k Using the PCA Data

# %%
# Create a list with the number of k-values from 1 to 11
k_values = list(range(1, 12))

# %%
# Create an empty list to store the inertia values
inertia_values2 = []

# Create a for loop to compute the inertia with each possible value of k
# Inside the loop:
# 1. Create a KMeans model using the loop counter for the n_clusters
# 2. Fit the model to the data using `df_market_data_pca`
# 3. Append the model.inertia_ to the inertia list
for k in k_values:
    kmeans = KMeans(n_clusters=k)
    kmeans.fit(pca_data)
    inertia_values2.append(kmeans.inertia_)
print(inertia_values2)
# Out:
# C:\Users\GamingPC\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\GamingPC\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\GamingPC\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ...

# %%
elbow_data2 = {'K': list(range(1, 12)),
              'Inertia': inertia_values2}

# Create a DataFrame with the data to plot the Elbow curve
elbow_df2 = pd.DataFrame(elbow_data2)
print(elbow_df2)
# Out:
#      K     Inertia
# 0    1  269.102703
# 1    2  175.890121
# 2    3   99.179766
# 3    4   46.988179
# 4    5   36.404552
# 5    6   26.957063
# 6    7   20.326757
# 7    8   16.738784
# 8    9   13.291977
# 9   10   10.261094
# 10  11    8.466119

# %%
# Plot a line chart with all the inertia values computed with 
# the different values of k to visually identify the optimal value for k.
line_plot = elbow_df2.hvplot.line(
    x='K',
    y='Inertia',
    xlabel='Number of Clusters (K)',
    ylabel='Inertia',
    title='Elbow Curve'
)
line_plot
# Out:
# :Curve   [K]   (Inertia)

# %% [markdown]
# #### Answer the following questions:
#
# * **Question:** What is the best value for `k` when using the PCA data?
#
#   * **Answer:** 4
#
#
# * **Question:** Does it differ from the best k value found using the original data?
#
#   * **Answer:** No

# %% [markdown]
# ### Cluster Cryptocurrencies with K-means Using the PCA Data

# %%
# Initialise the K-Means model using the best value for k
kmeans = KMeans(n_clusters=4)

# %%
# Fit the K-Means model using the PCA data
kmeans.fit(pca_data)
# Out:
# C:\Users\GamingPC\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\GamingPC\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# KMeans(n_clusters=4)

# %%
# Predict the clusters to group the cryptocurrencies using the PCA data
cluster_centers = kmeans.cluster_centers_

# Print the resulting array of cluster values.
labels = kmeans.labels_

# %%
# Create a copy of the DataFrame with the PCA data
normalized_df_copy = pca_data.copy()
normalized_df_copy['Cluster'] = labels
# Display sample data
print("DataFrame with Predicted Clusters:")
print(normalized_df_copy.head())
# Out:
# DataFrame with Predicted Clusters:
#                    PC1       PC2       PC3  Cluster
# coin_id
# bitcoin      -0.989271  0.715160  0.493822        0
# ethereum     -0.801150  0.386863  1.010012        0
# tether       -0.257238 -0.294368 -0.715437        1
# ripple       -0.289312 -0.354596 -0.561213        1
# bitcoin-cash -1.849888  1.754733  1.711689        0

# %%
# Create a scatter plot using hvPlot by setting 
# `x="PC1"` and `y="PC2"`. 
# Colour the graph points with the labels found using K-Means and 
# add the crypto name in the `hover_cols` parameter to identify 
# the cryptocurrency represented by each data point.
scatter_plot2 =normalized_df_copy.hvplot.scatter(
    x="PC1",
    y="PC2",
    by='Cluster',
    hover_cols=["crypto_name"],
    legend='bottom_right',
    title="Scatter Plot of PC1 vs PC2"
)

# Show the plot
scatter_plot2
# Out:
# :NdOverlay   [Cluster]
#    :Scatter   [PC1]   (PC2)

# %% [markdown]
# ### Visualise and Compare the Results
#
# In this section, you will visually analyse the cluster analysis results by contrasting the outcome with and without using the optimisation techniques.

# %%
elbow_composite_plot = (line_plot + line_plot1)

# Display the composite plot
elbow_composite_plot
# Out:
# :Layout
#    .Curve.I  :Curve   [K]   (Inertia)
#    .Curve.II :Curve   [K]   (Inertia)

# %%
# Composite plot to contrast the clusters
# YOUR CODE HERE!
Cluster_composite_plot = (scatter_plot + scatter_plot2)

# Display the composite plot
Cluster_composite_plot
# Out:
# :Layout
#    .NdOverlay.I  :NdOverlay   [Cluster]
#       :Scatter   [price_change_percentage_24h]   (price_change_percentage_7d,coin_id)
#    .NdOverlay.II :NdOverlay   [Cluster]
#       :Scatter   [PC1]   (PC2)

# %% [markdown]
# #### Answer the following question:
#
#   * **Question:** After visually analysing the cluster analysis results, what is the impact of using fewer features to cluster the data using K-Means?
#
#   * **Answer:** Using fewer features provides similar performance to the original model and we can clearly identify the clusters.
